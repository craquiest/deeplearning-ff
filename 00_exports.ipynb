# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

from google.colab import drive
import sys, os, shutil
from pathlib import Path
drive.mount("/content/drive", force_remount=True); my_drive = Path('/content/drive/My Drive/');
colabase = my_drive/'Colab Notebooks/'; course = my_drive/'github/fastai_course-v3/'
dlff = my_drive/'deeplearning-ff/'; pkl_path= dlff/'pickles'
os.chdir(dlff) #sys.path.append(str(dlff)) # cd {dlff}

# %%
#export
TEST = 'test'

# %% [markdown]
# ## Export

# %%
# !python notebook2script.py 00_exports.ipynb

# %% [markdown]
# ### How it works:

# %%
import json
d = json.load(open('00_exports.ipynb','r'))['cells']

# %%
d[1]
# Out:
# {'cell_type': 'code',
#  'execution_count': 0,
#  'metadata': {'colab': {}, 'colab_type': 'code', 'id': 'U0WKw9yDLUEy'},
#  'outputs': [],
#  'source': ['#export\n', "TEST = 'test'"]}
